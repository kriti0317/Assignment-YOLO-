# %%
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
model=YOLO("yolov8n.pt")
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 10.5MB/s]

# %%
results= model.train(data='streamlit/data.yaml',epochs=30,imgsz=1024, batch=8)
# Out:
# New https://pypi.org/project/ultralytics/8.3.133 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.132  Python-3.13.3 torch-2.7.0+cpu CPU (Intel Core(TM) i5-7200U 2.50GHz)
# ...

# %%
model=YOLO("/content/runs/detect/train2/weights/best.pt")
